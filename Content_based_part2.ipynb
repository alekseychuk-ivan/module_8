# %% [markdown]
# This jupiter notebook has a content recommender system. The system is based only on the description of the artist's genres, without reference to the year of release, song characteristics, etc.

# %%
import pandas as pd
import re
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
# load data
data = pd.read_csv('data.csv', ).drop('id', axis=1)
data.head().T
# Out:
#                                                                   0  \
# valence                                                      0.0594
# year                                                           1921
# acousticness                                                  0.982
# artists           ['Sergei Rachmaninoff', 'James Levine', 'Berli...
# danceability                                                  0.279
# duration_ms                                                  831667
# energy                                                        0.211
# explicit                                                          0
# instrumentalness                                              0.878
# key                                                              10
# liveness                                                      0.665
# loudness                                                    -20.096
# mode                                                              1
# name              Piano Concerto No. 3 in D Minor, Op. 30: III. ...
# popularity                                                        4
# release_date                                                   1921
# speechiness                                                  0.0366
# tempo                                                        80.954
#
#                                         1  \
# valence                             0.963
# year                                 1921
# acousticness                        0.732
# artists                    ['Dennis Day']
# danceability                        0.819
# duration_ms                        180533
# energy                              0.341
# explicit                                0
# instrumentalness                      0.0
# key                                     7
# liveness                             0.16
# loudness                          -12.441
# mode                                    1
# name              Clancy Lowered the Boom
# popularity                              5
# release_date                         1921
# speechiness                         0.415
# tempo                              60.936
#
#                                                                   2  \
# valence                                                      0.0394
# year                                                           1921
# acousticness                                                  0.961
# artists           ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...
# danceability                                                  0.328
# duration_ms                                                  500062
# energy                                                        0.166
# explicit                                                          0
# instrumentalness                                              0.913
# key                                                               3
# liveness                                                      0.101
# loudness                                                     -14.85
# mode                                                              1
# name                                                      Gati Bali
# popularity                                                        5
# release_date                                                   1921
# speechiness                                                  0.0339
# tempo                                                       110.339
#
#                                  3                            4
# valence                      0.165                        0.253
# year                          1921                         1921
# acousticness                 0.967                        0.957
# artists           ['Frank Parker']               ['Phil Regan']
# danceability                 0.275                        0.418
# duration_ms                 210000                       166693
# energy                       0.309                        0.193
# explicit                         0                            0
# instrumentalness          0.000028                     0.000002
# key                              5                            3
# liveness                     0.381                        0.229
# loudness                    -9.316                      -10.096
# mode                             1                            1
# name                     Danny Boy  When Irish Eyes Are Smiling
# popularity                       3                            2
# release_date                  1921                         1921
# speechiness                 0.0354                        0.038
# tempo                      100.109                      101.665

# %%
# cast to date to year
data['release_date'] = [x[:4] for x in data.release_date]
data.release_date = data.release_date.astype('int64')

# %%
# data.info()

# %%
# data.fillna(0, inplace=True)

# %%
data.drop_duplicates(['name', 'artists'], inplace=True)

# %%
# data.shape

# %%
# data.artists.nunique()

# %%
def clear(text):
    '''
    converts string that appears to be list to an actual list after removing ',",[,] symbols and splitting it by ,
    
    Parameter:
        text (string )- string that need to be converted into list
    
    Returns: 
        l (List) - returns list of the string
    
    '''
    # text = re.sub(r" ","_",text)
    text = re.sub("[\'\"\[\]]","",text).split(", ")
    return text

def clear_v2(text):
    '''
    converts string that appears to be list to an actual list after removing ',",[,] symbols and splitting it by ,
    
    Parameter:
        text (string )- string that need to be converted into list
    
    Returns: 
        l (string) - returns string
    
    '''
    # text = re.sub(r" ","_",text)
    # print(text)
    text = re.sub("[\'\"\[\]]","", text)
    return text    

def clear_v1(text):
    '''
    converts string that appears to be list to an actual list after removing ',",[,] symbols and splitting it by ,
    
    Parameter:
        text (string )- string that need to be converted into list
    
    Returns: 
        l (List) - returns list of the string
    
    '''
    # text = re.sub(r" ","_",text)
    text = re.sub("[\'\"\[\]]","",text).split(", ")
    return text[0]

# %% [markdown]
# Due to the fact that there can be several authors in the artist cell, it is necessary to separate them into separate cells or use the clear_in function clear_v1

# %%
data.artists = data.artists.apply(clear)
data.head().T
# Out:
#                                                                   0  \
# valence                                                      0.0594
# year                                                           1921
# acousticness                                                  0.982
# artists           [Sergei Rachmaninoff, James Levine, Berliner P...
# danceability                                                  0.279
# duration_ms                                                  831667
# energy                                                        0.211
# explicit                                                          0
# instrumentalness                                              0.878
# key                                                              10
# liveness                                                      0.665
# loudness                                                    -20.096
# mode                                                              1
# name              Piano Concerto No. 3 in D Minor, Op. 30: III. ...
# popularity                                                        4
# release_date                                                   1921
# speechiness                                                  0.0366
# tempo                                                        80.954
#
#                                         1  \
# valence                             0.963
# year                                 1921
# acousticness                        0.732
# artists                      [Dennis Day]
# danceability                        0.819
# duration_ms                        180533
# energy                              0.341
# explicit                                0
# instrumentalness                      0.0
# key                                     7
# liveness                             0.16
# loudness                          -12.441
# mode                                    1
# name              Clancy Lowered the Boom
# popularity                              5
# release_date                         1921
# speechiness                         0.415
# tempo                              60.936
#
#                                                                   2  \
# valence                                                      0.0394
# year                                                           1921
# acousticness                                                  0.961
# artists           [KHP Kridhamardawa Karaton Ngayogyakarta Hadin...
# danceability                                                  0.328
# duration_ms                                                  500062
# energy                                                        0.166
# explicit                                                          0
# instrumentalness                                              0.913
# key                                                               3
# liveness                                                      0.101
# loudness                                                     -14.85
# mode                                                              1
# name                                                      Gati Bali
# popularity                                                        5
# release_date                                                   1921
# speechiness                                                  0.0339
# tempo                                                       110.339
#
#                                3                            4
# valence                    0.165                        0.253
# year                        1921                         1921
# acousticness               0.967                        0.957
# artists           [Frank Parker]                 [Phil Regan]
# danceability               0.275                        0.418
# duration_ms               210000                       166693
# energy                     0.309                        0.193
# explicit                       0                            0
# instrumentalness        0.000028                     0.000002
# key                            5                            3
# liveness                   0.381                        0.229
# loudness                  -9.316                      -10.096
# mode                           1                            1
# name                   Danny Boy  When Irish Eyes Are Smiling
# popularity                     3                            2
# release_date                1921                         1921
# speechiness               0.0354                        0.038
# tempo                    100.109                      101.665

# %%
data = data.explode("artists",ignore_index=True)
data.head()
# Out:
#    valence  year  acousticness  \
# 0   0.0594  1921         0.982
# 1   0.0594  1921         0.982
# 2   0.0594  1921         0.982
# 3   0.9630  1921         0.732
# 4   0.0394  1921         0.961
#
#                                              artists  danceability  \
# 0                                Sergei Rachmaninoff         0.279
# 1                                       James Levine         0.279
# 2                            Berliner Philharmoniker         0.279
# 3                                         Dennis Day         0.819
# 4  KHP Kridhamardawa Karaton Ngayogyakarta Hadini...         0.328
#
#    duration_ms  energy  explicit  instrumentalness  key  liveness  loudness  \
# 0       831667   0.211         0             0.878   10     0.665   -20.096
# 1       831667   0.211         0             0.878   10     0.665   -20.096
# 2       831667   0.211         0             0.878   10     0.665   -20.096
# 3       180533   0.341         0             0.000    7     0.160   -12.441
# 4       500062   0.166         0             0.913    3     0.101   -14.850
#
#    mode                                               name  popularity  \
# 0     1  Piano Concerto No. 3 in D Minor, Op. 30: III. ...           4
# 1     1  Piano Concerto No. 3 in D Minor, Op. 30: III. ...           4
# 2     1  Piano Concerto No. 3 in D Minor, Op. 30: III. ...           4
# 3     1                            Clancy Lowered the Boom           5
# 4     1                                          Gati Bali           5
#
#    release_date  speechiness    tempo
# 0          1921       0.0366   80.954
# 1          1921       0.0366   80.954
# 2          1921       0.0366   80.954
# 3          1921       0.4150   60.936
# 4          1921       0.0339  110.339

# %%
# data.info()

# %%
# data.artists.tolist()

# %%
# load w_genres file
genres_w = pd.read_csv('data_w_genres.csv')

# %%
genres_w.head().T
# Out:
#                                                  0                          1  \
# genres                              ['show tunes']                         []
# artists           "Cats" 1981 Original London Cast  "Cats" 1983 Broadway Cast
# acousticness                              0.590111                   0.862538
# danceability                              0.467222                   0.441731
# duration_ms                          250318.555556                   287280.0
# energy                                    0.394003                   0.406808
# instrumentalness                            0.0114                   0.081158
# liveness                                  0.290833                   0.315215
# loudness                                   -14.448                     -10.69
# speechiness                               0.210389                   0.176212
# tempo                                   117.518111                 103.044154
# valence                                     0.3895                   0.268865
# popularity                               38.333333                  30.576923
# key                                              5                          5
# mode                                             1                          1
# count                                            9                         26
#
#                                                             2  \
# genres                                                     []
# artists           "Fiddler On The Roof” Motion Picture Chorus
# acousticness                                         0.856571
# danceability                                         0.348286
# duration_ms                                          328920.0
# energy                                               0.286571
# instrumentalness                                     0.024593
# liveness                                             0.325786
# loudness                                           -15.230714
# speechiness                                          0.118514
# tempo                                               77.375857
# valence                                              0.354857
# popularity                                          34.857143
# key                                                         0
# mode                                                        1
# count                                                       7
#
#                                                                3  \
# genres                                                        []
# artists           "Fiddler On The Roof” Motion Picture Orchestra
# acousticness                                            0.884926
# danceability                                            0.425074
# duration_ms                                        262890.962963
# energy                                                   0.24577
# instrumentalness                                        0.073587
# liveness                                                0.275481
# loudness                                               -15.63937
# speechiness                                               0.1232
# tempo                                                   88.66763
# valence                                                  0.37203
# popularity                                             34.851852
# key                                                            0
# mode                                                           1
# count                                                         27
#
#                                                                   4
# genres                                                           []
# artists           "Joseph And The Amazing Technicolor Dreamcoat"...
# acousticness                                               0.510714
# danceability                                               0.467143
# duration_ms                                           270436.142857
# energy                                                     0.488286
# instrumentalness                                             0.0094
# liveness                                                      0.195
# loudness                                                 -10.236714
# speechiness                                                0.098543
# tempo                                                    122.835857
# valence                                                    0.482286
# popularity                                                     43.0
# key                                                               5
# mode                                                              1
# count                                                             7

# %%
genres_w.artists = genres_w.artists.apply(clear_v2)
genres_w.genres = genres_w.genres.apply(clear_v2)
genres_w.head().T
# Out:
#                                                0                        1  \
# genres                                show tunes
# artists           Cats 1981 Original London Cast  Cats 1983 Broadway Cast
# acousticness                            0.590111                 0.862538
# danceability                            0.467222                 0.441731
# duration_ms                        250318.555556                 287280.0
# energy                                  0.394003                 0.406808
# instrumentalness                          0.0114                 0.081158
# liveness                                0.290833                 0.315215
# loudness                                 -14.448                   -10.69
# speechiness                             0.210389                 0.176212
# tempo                                 117.518111               103.044154
# valence                                   0.3895                 0.268865
# popularity                             38.333333                30.576923
# key                                            5                        5
# mode                                           1                        1
# count                                          9                       26
#
#                                                            2  \
# genres
# artists           Fiddler On The Roof” Motion Picture Chorus
# acousticness                                        0.856571
# danceability                                        0.348286
# duration_ms                                         328920.0
# energy                                              0.286571
# instrumentalness                                    0.024593
# liveness                                            0.325786
# loudness                                          -15.230714
# speechiness                                         0.118514
# tempo                                              77.375857
# valence                                             0.354857
# popularity                                         34.857143
# key                                                        0
# mode                                                       1
# count                                                      7
#
#                                                               3  \
# genres
# artists           Fiddler On The Roof” Motion Picture Orchestra
# acousticness                                           0.884926
# danceability                                           0.425074
# duration_ms                                       262890.962963
# energy                                                  0.24577
# instrumentalness                                       0.073587
# liveness                                               0.275481
# loudness                                              -15.63937
# speechiness                                              0.1232
# tempo                                                  88.66763
# valence                                                 0.37203
# popularity                                            34.851852
# key                                                           0
# mode                                                          1
# count                                                        27
#
#                                                                   4
# genres
# artists           Joseph And The Amazing Technicolor Dreamcoat 1...
# acousticness                                               0.510714
# danceability                                               0.467143
# duration_ms                                           270436.142857
# energy                                                     0.488286
# instrumentalness                                             0.0094
# liveness                                                      0.195
# loudness                                                 -10.236714
# speechiness                                                0.098543
# tempo                                                    122.835857
# valence                                                    0.482286
# popularity                                                     43.0
# key                                                               5
# mode                                                              1
# count                                                             7

# %% [markdown]
# Merge data and genres_w file

# %%
data = data.merge(genres_w[['genres', 'artists']], how='left', on='artists')
data.head().T
# Out:
#                                                                   0  \
# valence                                                      0.0594
# year                                                           1921
# acousticness                                                  0.982
# artists                                         Sergei Rachmaninoff
# danceability                                                  0.279
# duration_ms                                                  831667
# energy                                                        0.211
# explicit                                                          0
# instrumentalness                                              0.878
# key                                                              10
# liveness                                                      0.665
# loudness                                                    -20.096
# mode                                                              1
# name              Piano Concerto No. 3 in D Minor, Op. 30: III. ...
# popularity                                                        4
# release_date                                                   1921
# speechiness                                                  0.0366
# tempo                                                        80.954
# genres            classical, post-romantic era, russian romantic...
#
#                                                                   1  \
# valence                                                      0.0594
# year                                                           1921
# acousticness                                                  0.982
# artists                                                James Levine
# danceability                                                  0.279
# duration_ms                                                  831667
# energy                                                        0.211
# explicit                                                          0
# instrumentalness                                              0.878
# key                                                              10
# liveness                                                      0.665
# loudness                                                    -20.096
# mode                                                              1
# name              Piano Concerto No. 3 in D Minor, Op. 30: III. ...
# popularity                                                        4
# release_date                                                   1921
# speechiness                                                  0.0366
# tempo                                                        80.954
# genres            classical performance, opera, orchestral perfo...
#
#                                                                   2  \
# valence                                                      0.0594
# year                                                           1921
# acousticness                                                  0.982
# artists                                     Berliner Philharmoniker
# danceability                                                  0.279
# duration_ms                                                  831667
# energy                                                        0.211
# explicit                                                          0
# instrumentalness                                              0.878
# key                                                              10
# liveness                                                      0.665
# loudness                                                    -20.096
# mode                                                              1
# name              Piano Concerto No. 3 in D Minor, Op. 30: III. ...
# popularity                                                        4
# release_date                                                   1921
# speechiness                                                  0.0366
# tempo                                                        80.954
# genres            classical, classical performance, german orche...
#
#                                         3  \
# valence                             0.963
# year                                 1921
# acousticness                        0.732
# artists                        Dennis Day
# danceability                        0.819
# duration_ms                        180533
# energy                              0.341
# explicit                                0
# instrumentalness                      0.0
# key                                     7
# liveness                             0.16
# loudness                          -12.441
# mode                                    1
# name              Clancy Lowered the Boom
# popularity                              5
# release_date                         1921
# speechiness                         0.415
# tempo                              60.936
# genres
#
#                                                                   4
# valence                                                      0.0394
# year                                                           1921
# acousticness                                                  0.961
# artists           KHP Kridhamardawa Karaton Ngayogyakarta Hadini...
# danceability                                                  0.328
# duration_ms                                                  500062
# energy                                                        0.166
# explicit                                                          0
# instrumentalness                                              0.913
# key                                                               3
# liveness                                                      0.101
# loudness                                                     -14.85
# mode                                                              1
# name                                                      Gati Bali
# popularity                                                        5
# release_date                                                   1921
# speechiness                                                  0.0339
# tempo                                                       110.339
# genres

# %%
# data[data.genres.isnull()]

# %%
# # remove gaps
data.genres.fillna('', inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 211068 entries, 0 to 211067
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   valence           211068 non-null  float64
#  1   year              211068 non-null  int64
#  2   acousticness      211068 non-null  float64
#  3   artists           211068 non-null  object
#  4   danceability      211068 non-null  float64
#  5   duration_ms       211068 non-null  int64
#  6   energy            211068 non-null  float64
#  7   explicit          211068 non-null  int64
#  8   instrumentalness  211068 non-null  float64
#  9   key               211068 non-null  int64
#  10  liveness          211068 non-null  float64
#  11  loudness          211068 non-null  float64
#  12  mode              211068 non-null  int64
#  13  name              211068 non-null  object
#  14  popularity        211068 non-null  int64
#  15  release_date      211068 non-null  int64
#  16  speechiness       211068 non-null  float64
#  17  tempo             211068 non-null  float64
#  18  genres            211068 non-null  object
# dtypes: float64(9), int64(7), object(3)
# memory usage: 32.2+ MB

# %%
start_year = 2014

# %%
temp = data[data.year >= start_year].reset_index(drop=True)
temp.head().T
# Out:
#                                    0  \
# valence                        0.591
# year                            2014
# acousticness                  0.0489
# artists                Ariana Grande
# danceability                   0.525
# duration_ms                   204093
# energy                         0.621
# explicit                           0
# instrumentalness                 0.0
# key                                7
# liveness                       0.294
# loudness                      -7.364
# mode                               1
# name                   Santa Tell Me
# popularity                        86
# release_date                    2014
# speechiness                    0.116
# tempo                          191.9
# genres            pop, post-teen pop
#
#                                                                   1  \
# valence                                                       0.463
# year                                                           2014
# acousticness                                                  0.301
# artists                                                     J. Cole
# danceability                                                  0.692
# duration_ms                                                  292987
# energy                                                        0.521
# explicit                                                          1
# instrumentalness                                                0.0
# key                                                              10
# liveness                                                     0.0565
# loudness                                                     -8.465
# mode                                                              0
# name                                                 No Role Modelz
# popularity                                                       84
# release_date                                                   2014
# speechiness                                                    0.33
# tempo                                                        100.45
# genres            conscious hip hop, hip hop, north carolina hip...
#
#                                                      2  \
# valence                                           0.51
# year                                              2014
# acousticness                                     0.431
# artists                                      Vance Joy
# danceability                                     0.484
# duration_ms                                     204280
# energy                                           0.731
# explicit                                             0
# instrumentalness                                   0.0
# key                                                  1
# liveness                                         0.151
# loudness                                        -6.694
# mode                                                 1
# name                                           Riptide
# popularity                                          78
# release_date                                      2014
# speechiness                                     0.0379
# tempo                                          101.654
# genres            folk-pop, modern rock, pop, pop rock
#
#                                                                   3  \
# valence                                                       0.584
# year                                                           2014
# acousticness                                                 0.0751
# artists                                                     J. Cole
# danceability                                                  0.517
# duration_ms                                                  239320
# energy                                                        0.705
# explicit                                                          1
# instrumentalness                                                0.0
# key                                                               6
# liveness                                                      0.128
# loudness                                                     -8.205
# mode                                                              0
# name                                                     Wet Dreamz
# popularity                                                       79
# release_date                                                   2014
# speechiness                                                   0.364
# tempo                                                       175.906
# genres            conscious hip hop, hip hop, north carolina hip...
#
#                                                                   4
# valence                                                       0.211
# year                                                           2014
# acousticness                                                   0.22
# artists                                               Ty Dolla $ign
# danceability                                                  0.805
# duration_ms                                                  242983
# energy                                                         0.33
# explicit                                                          1
# instrumentalness                                                0.0
# key                                                               1
# liveness                                                      0.105
# loudness                                                     -8.712
# mode                                                              0
# name              Or Nah (feat. The Weeknd, Wiz Khalifa & DJ Mus...
# popularity                                                       80
# release_date                                                   2014
# speechiness                                                     0.1
# tempo                                                        121.97
# genres                  hip hop, pop, pop rap, r&b, trap, trap soul

# %%
# search numeric columns
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
num_cols = temp.select_dtypes(include=numerics).columns.tolist()

# %%
# use scaler
scaler = StandardScaler()
# scaler = MinMaxScaler()

# %%
temp[num_cols] = scaler.fit_transform(temp[num_cols])
temp.head()
# Out:
#     valence      year  acousticness        artists  danceability  duration_ms  \
# 0  0.598452 -1.544905     -0.733880  Ariana Grande     -0.668070    -0.203988
# 1  0.046881 -1.544905      0.183260        J. Cole      0.307359     1.141832
# 2  0.249411 -1.544905      0.656201      Vance Joy     -0.907546    -0.201156
# 3  0.568288 -1.544905     -0.638565        J. Cole     -0.714797     0.329335
# 4 -1.039026 -1.544905     -0.111418  Ty Dolla $ign      0.967379     0.384791
#
#      energy  explicit  instrumentalness       key  liveness  loudness  \
# 0  0.016145 -0.824991         -0.312036  0.484645  0.693312 -0.001137
# 1 -0.473560  1.212134         -0.312036  1.312028 -0.845995 -0.251229
# 2  0.554820 -0.824991         -0.312036 -1.170120 -0.233513  0.151053
# 3  0.427497  1.212134         -0.312036  0.208851 -0.382583 -0.192170
# 4 -1.408896  1.212134         -0.312036 -1.170120 -0.531652 -0.307335
#
#        mode                                               name  popularity  \
# 0  0.815546                                      Santa Tell Me    1.568205
# 1 -1.226173                                     No Role Modelz    1.436121
# 2  0.815546                                            Riptide    1.039872
# 3 -1.226173                                         Wet Dreamz    1.105914
# 4 -1.226173  Or Nah (feat. The Weeknd, Wiz Khalifa & DJ Mus...    1.171955
#
#    release_date  speechiness     tempo  \
# 0     -1.544905    -0.063551  2.311953
# 1     -1.544905     1.724558 -0.660965
# 2     -1.544905    -0.716127 -0.621824
# 3     -1.544905     2.008650  1.792010
# 4     -1.544905    -0.197242  0.038622
#
#                                               genres
# 0                                 pop, post-teen pop
# 1  conscious hip hop, hip hop, north carolina hip...
# 2               folk-pop, modern rock, pop, pop rock
# 3  conscious hip hop, hip hop, north carolina hip...
# 4        hip hop, pop, pop rap, r&b, trap, trap soul

# %%
# temp.reset_index(inplace=True, drop=True)
titles = temp['name'] + ' | ' + temp['artists']
indices = pd.Series(temp.index, index=temp['name'])

# %%
# create tfidf matrix
vectorizer = TfidfVectorizer(ngram_range=(1, 3))
# vectorizer = CountVectorizer()
tfidf = vectorizer.fit_transform(temp.genres)
tfidf.shape
# Out:
# (18601, 9653)

# %%
def create_df(vector, x):
  df = pd.DataFrame(x.toarray(), columns=vector.get_feature_names())
  
  return df

# %%
df = create_df(vectorizer, tfidf)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
temp = pd.concat([temp, df], axis=1)

# %%
temp.shape
# Out:
# (18601, 9672)

# %%
vec = temp.drop(['artists', 'name', 'genres'], axis=1).to_numpy()

# %%
# to estimate distances between vectors
cosine = linear_kernel(vec, vec)

# %%
# cosine[0]

# %%
def get_recommendations(title, cosine_sim=cosine, indices=indices):
    idx = indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:31]
    movie_indices = [i[0] for i in sim_scores]
    return titles.iloc[movie_indices]

# %%
get_recommendations('Santa Tell Me', cosine).head(20)
# Out:
# 75                       Drunk On A Plane | Dierks Bentley
# 17162                         Be Our Guest | Mitchell Hope
# 17163                           Be Our Guest | Spencer Lee
# 17164                            Be Our Guest | Kala Balch
# 17165                     Be Our Guest | Marco Marinangeli
# 74                                      Animals | Maroon 5
# 2067                              Salad Days | Mac DeMarco
# 5721                Gonna Know We Were Here | Jason Aldean
# 2226                        Day Drinking | Little Big Town
# 2239             Qué Tal Si Eres Tu | Los Tigres Del Norte
# 13439                 Pilares de Cristal | Chalino Sanchez
# 2059                                    Just One Day | BTS
# 176                         I Wanna Get Better | Bleachers
# 169                          Leave The Night On | Sam Hunt
# 15158                 El Caballo De Pepe | Grupo Laberinto
# 2062     Cecilia And The Satellite | Andrew McMahon in ...
# 292                      679 (feat. Remy Boyz) | Fetty Wap
# 23              She Looks So Perfect | 5 Seconds of Summer
# 293                      679 (feat. Remy Boyz) | Remy Boyz
# 2095                       Sun Daze | Florida Georgia Line
# dtype: object

# %%
get_recommendations('Am I Wrong', cosine).head(20)
# Out:
# 5728                                      Perdoname | DyCy
# 5729                            Perdoname | Adrian Delgado
# 13331    Rock Me - Live Version from The Motion Picture...
# 2226                        Day Drinking | Little Big Town
# 13368               Sweet Child O' Mine - Acoustic | Slash
# 13369    Sweet Child O' Mine - Acoustic | Myles Kennedy...
# 13638                   Hair (feat. Sean Paul) | Sean Paul
# 13637                  Hair (feat. Sean Paul) | Little Mix
# 9658      Will The Circle Be Unbroken - Live | Pat Monahan
# 9648     Will The Circle Be Unbroken - Live | Warren Ha...
# 9649     Will The Circle Be Unbroken - Live | Derek Trucks
# 9650     Will The Circle Be Unbroken - Live | Susan Ted...
# 9651     Will The Circle Be Unbroken - Live | Devon Allman
# 9652     Will The Circle Be Unbroken - Live | Robert Ra...
# 9653       Will The Circle Be Unbroken - Live | Jimmy Hall
# 9654        Will The Circle Be Unbroken - Live | Sam Moore
# 9655           Will The Circle Be Unbroken - Live | Keb Mo
# 9656     Will The Circle Be Unbroken - Live | Brantley ...
# 9657         Will The Circle Be Unbroken - Live | Dr. John
# 9659       Will The Circle Be Unbroken - Live | John Hiatt
# dtype: object

# %% [markdown]
# as we can see, when using additional parameters for the content recommender system, the results can differ significantly.
# for better prediction, it may be worth trying to apply clustering and dimensionality reduction methods.
